# %%
dbutils.secrets.listScopes()

# %%
dbutils.secrets.list('dealshare-gcp')

# %%
# %sh
nc -vz 172.40.2.88 27017

# %%
# %sh
nc -vz 172.40.2.207 3306

# %%
dbutils.secrets.list("referral_dataset")

# %%
d=dbutils.secrets.get(scope = "dealshare-gcp", key ="sa_dbx_aws")
for i in d:
    print(i, end=" ")

# %%
dbutils.secrets.list('dealshare-gcp')
