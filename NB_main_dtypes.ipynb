# %%
# %run ./NB_common_utils_dtypes

# %%
# ============================================================
# WIDGETS SET
# ============================================================

dbutils.widgets.text("catalog_path","")
dbutils.widgets.text("mysql_scope_name","")
dbutils.widgets.text("bq_scope_name","")
dbutils.widgets.text("bq_sa_name","")
dbutils.widgets.text("target_table_prefix","")
dbutils.widgets.text("secret_prefix_bq","")
dbutils.widgets.text("start_date","")
dbutils.widgets.text("end_date","")

# %%
# ============================================================
# WIDGETS GET
# ============================================================

catalog_path=dbutils.widgets.get("catalog_path")
mysql_scope_name = dbutils.widgets.get("mysql_scope_name")
bq_scope_name = dbutils.widgets.get("bq_scope_name")
bq_sa_name = dbutils.widgets.get("bq_sa_name")
target_table_prefix = dbutils.widgets.get("target_table_prefix")
secret_prefix_bq = dbutils.widgets.get("secret_prefix_bq")
start_date = dbutils.widgets.get("start_date")
end_date = dbutils.widgets.get("end_date")

# %%
import base64
run_pipeline(catalog_path, mysql_scope_name, bq_scope_name, bq_sa_name, secret_prefix_bq, target_table_prefix, start_date, end_date)
